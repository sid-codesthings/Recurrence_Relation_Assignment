# %%
'''
1. Find the value of T(2) for the recurrence relation T(n) = 3T(n-1) + 12n , given that T(0) = 5.

T(1) = 3T(0) + 12*1 --> T(1) = 3 * 5 + 12 = 27
T(2) = 3T(1) + 12*2 = 3 * 27 + 24 = 81 + 24 = 105

2. Given a recurrence relation , solve it using the substitution method :

a. T(n) = T(n-1) + c 

T(n-1) = T(n-2) + c
T(n-2) = T(n-3) + c

So , T(n) = T(n-2) + c + c = T(n-3) + c + c + c = T(n-3) + 3c = T(n-k) + kc 
Assuming T(n) = 1 for n <= 1 , we set n-k = 1 , k = n-1 
In that case , T(n) = T(1) + (n-1)c = 1 + (n-1)c 

then it will be a linear time complexity O(n) .

b. T(n) = 2T(n/2) + n

T(n/2) = 2T(n/4) + (n/2) 
T(n/4) = 2T(n/8) + (n/4)  
T(n/8) = 2T(n/16) + (n/8) 

Hence T(n) = 4T(n/4) + 2n ,
T(n) = 8T(n/8) + 3n ,
T(n) = 16T(n/16) + 4n

so the generalized solution is T(n) = (2^k) T(n/2^k) + kn

c. T(n) = 2T(n/2) + c

T(n/2) = 2T(n/4) + c
T(n/4) = 2T(n/8) + c
T(n/8) = 2T(n/16) + c

T(n) = 4T(n/4) + 3c ,
T(n) = 8T(n/8) + 7c , 
T(n) = 16T(n/16) + 15c

So the generalized solution is T(n) = kT(n/k) + (k-1)c

d. T(n) = T(n/2) + c

T(n/2) = T(n/4) + c
T(n/4) = T(n/8) + c
T(n/8) = T(n/16) + c

T(n) = T(n/4) + c + c = T(n/8) + c + c + c = T(n/16) + c + c + c + c = T(n/16) + 4c
So the generalized solution is ,
T(n) = T(n/2^k) + kc 

3.  Given a recurrence relation, solve it using the recursive tree approach :
a. T(n) = 2T(n-1) + 1

T(n) = T(n-1) + T(n-1) + 1

                                     n    --------------> 1 = 2^0
                          n-1                   n-1    ---------->  1 + 1 = 2^1
                   n-2           n-2      n-2           n-2  -----------> 1 + 1 + 1 + 1 = 4 = 2^2
           n-3         ............................         n-3 -----------> 1 + 1 + 1 + 1 + 1 + 1 + 1 + 1 = 8 = 2^3
           
So if there are k levels then the solution is 
2^0 + 2^1 + 2^2 + 2^3 + ..... + 2^k
= a(r^k - 1)/r-1 = 2^k - 1
 





b. T(n) = 2T(n/2) + n

                                    n ---------> n
                       n/2                     n/2   ---> n/2 + n/2 = n cost
                 n/4        n/4             n/4      n/4   --- > 4 * n/4 = n 
            n/8      n/8   ............... n/8        n/8   --- > 8 * n/8 = n

So if there are k levels , then nk is the solution where k has to be found out
by equating the n/2^k = base case value 

If for eg , base case

n = 2^k
k = log n (base 2) hence complexity will be O(nk) = O(n*log n) 

'''
